# %%
#Explore the WRDS dataset

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from datetime import datetime, date

company = pd.read_csv("company_data.csv")

# %%
#Exploratory Data Analysis

#What do we have?
company.shape #780 rows and 27 columns
# Out:
# (780, 27)

# %%
company.head(3) #We have yearly data from 2005 to 2020 for 52 companies
# Out:
#    Year Ticker  ...  Logarithm_Total_Sales  Profitable
# 0  2005    AEE  ...               8.821732        True
# 1  2006    AEE  ...               8.836374        True
# 2  2007    AEE  ...               8.928773        True
#
# [3 rows x 27 columns]

# %%
#Check for NAs
company.isna().sum()
# Out:
# Year                                                   0
# Ticker                                                 0
# Environmental Disclosure Score                       144
# GHG Scope 1                                          382
# Total Energy Consumption                             537
# Change_in_EDS                                          0
# Change_in_GHG                                          0
# Change_in_TEC                                          0
# Ratio of GHG Emissions to Total Assets               382
# Ratio of GHG Emissions to Total Sales                382
# Ratio of Total Energy Consumption to Total Assets    537
# Ratio of Total Energy Consumption to Total Sales     537
# cusip                                                 23
# Company                                               23
# Total_Assets                                          23
# Net_Income                                            23
# ...

# %%
#Drop duplicates if any
company.drop_duplicates(inplace=True) # We dont have duplicates

# %%
plt.figure(figsize=(10,5))
sns.heatmap(company.isnull(), cbar=True).set(title='Missing Data in the dataset')
plt.show()

# %%
company.fillna(0)
# Out:
#      Year Ticker  ...  Logarithm_Total_Sales  Profitable
# 0    2005    AEE  ...               8.821732        True
# 1    2006    AEE  ...               8.836374        True
# 2    2007    AEE  ...               8.928773        True
# 3    2008    AEE  ...               8.966867        True
# 4    2009    AEE  ...               8.866441        True
# ..    ...    ...  ...                    ...         ...
# 775  2015    XOM  ...              12.375013        True
# 776  2016    XOM  ...              12.193585        True
# 777  2017    XOM  ...              12.376499        True
# 778  2018    XOM  ...              12.540156        True
# 779  2019    XOM  ...              12.451302        True
#
# [780 rows x 27 columns]
