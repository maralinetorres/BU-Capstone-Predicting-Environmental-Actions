# %% [markdown]
# ## Environmental Impact dataset - Data Cleaning
#
# In this notebook, we are cleaning the format for a few columns in the Environmental Impact dataset retrieved from the Harvard Study.
#
# We will continue using this dataset in several notebooks

# %%
import pandas as pd
df = pd.read_csv('/Users/maralinetorres/Documents/GitHub/Predicting-Environmental-and-Social-Actions/Datasets/Final-Sample-External-with-ISINs.csv')
column_list = []
for column in df.columns:
    column_list.append(column.replace(' ', ''))
df.columns = column_list
df.head()
# Out:
#            ISIN  Year         CompanyName         Country  \
# 0  GB00BMX64W89  2019            Saga plc  United Kingdom
# 1  MYL1818OO003  2019  BURSA MALAYSIA BHD        Malaysia
# 2  GB0031638363  2019  INTERTEK GROUP PLC  United Kingdom
# 3  ZAE000079711  2019         JSE LIMITED    South Africa
# 4  FR0006174348  2019   BUREAU VERITAS SA          France
#
#                                   Industry(Exiobase)  \
# 0  Activities auxiliary to financial intermediati...
# 1  Activities auxiliary to financial intermediati...
# 2  Activities auxiliary to financial intermediati...
# 3  Activities auxiliary to financial intermediati...
# 4  Activities auxiliary to financial intermediati...
#
#   EnvironmentalIntensity(Sales) EnvironmentalIntensity(OpInc)  \
# 0                        -2.89%                       -13.03%
# 1                        -1.68%                        -3.47%
# 2                        -1.53%                        -9.49%
# 3                        -1.46%                           NaN
# 4                        -0.70%                        -5.10%
#
#   TotalEnvironmentalCost WorkingCapacity FishProductionCapacity  ...  \
# 0            -31,842,309     -31,150,754                 -7,184  ...
# 1             -1,968,379      -1,924,910                   -451  ...
# 2            -60,599,272     -59,281,663                -13,774  ...
# 3             -2,290,124      -2,239,814                   -510  ...
# 4            -39,978,650     -39,107,612                 -9,330  ...
#
#        SDG6 SDG12.2 SDG14.1 SDG14.2 SDG14.3 SDG14.c SDG15.1 SDG15.2 SDG15.5  \
# 0  -170,776  -1,059      -5      -1  -3,585      -6      71      71  -1,297
# 1   -11,502    -168      -1      -1    -222      -2      10      10     -79
# 2  -324,960  -3,804     -17      -4  -6,861     -20     254     254  -2,470
# 3   -12,200    -901       0      -1    -253       0      -3      -3     -93
# 4  -214,438  -4,116     -38      -9  -4,607     -45     586     586  -1,633
#
#   %Imputed
# 0       1%
# 1       4%
# 2       1%
# 3       2%
# 4       3%
#
# [5 rows x 34 columns]

# %% [markdown]
# Noticed the company name and country values have spaces at the beginning and end.

# %%
companies = df.CompanyName.tolist()
com = []

countries = df.Country.tolist()
country = []

for c in companies:
    com.append(c.lstrip().rstrip())

for c in countries:
    country.append(c.lstrip().rstrip())
    
df['CompanyName'] = com
df['Country'] = country

# %% [markdown]
# Also, we will fix that in the next cells.

# %%
def percent_to_float(s):
    return float(s.strip('%')) / 100.0

replace_dict = {'(':'',')':'', ' ' : '', ',' : ''}
def paranthesis_to_minus(value):
    for i, j in replace_dict.items():
        value = value.replace(i, j)
    value = int(f'-{value}')
    return value

df['Env_intensity'] = df['EnvironmentalIntensity(Sales)'].apply(percent_to_float)

# %%
df.head()
# Out:
#            ISIN  Year         CompanyName         Country  \
# 0  GB00BMX64W89  2019            Saga plc  United Kingdom
# 1  MYL1818OO003  2019  BURSA MALAYSIA BHD        Malaysia
# 2  GB0031638363  2019  INTERTEK GROUP PLC  United Kingdom
# 3  ZAE000079711  2019         JSE LIMITED    South Africa
# 4  FR0006174348  2019   BUREAU VERITAS SA          France
#
#                                   Industry(Exiobase)  \
# 0  Activities auxiliary to financial intermediati...
# 1  Activities auxiliary to financial intermediati...
# 2  Activities auxiliary to financial intermediati...
# 3  Activities auxiliary to financial intermediati...
# 4  Activities auxiliary to financial intermediati...
#
#   EnvironmentalIntensity(Sales) EnvironmentalIntensity(OpInc)  \
# 0                        -2.89%                       -13.03%
# 1                        -1.68%                        -3.47%
# 2                        -1.53%                        -9.49%
# 3                        -1.46%                           NaN
# 4                        -0.70%                        -5.10%
#
#   TotalEnvironmentalCost WorkingCapacity FishProductionCapacity  ... SDG12.2  \
# 0            -31,842,309     -31,150,754                 -7,184  ...  -1,059
# 1             -1,968,379      -1,924,910                   -451  ...    -168
# 2            -60,599,272     -59,281,663                -13,774  ...  -3,804
# 3             -2,290,124      -2,239,814                   -510  ...    -901
# 4            -39,978,650     -39,107,612                 -9,330  ...  -4,116
#
#   SDG14.1 SDG14.2 SDG14.3 SDG14.c SDG15.1 SDG15.2 SDG15.5 %Imputed  \
# 0      -5      -1  -3,585      -6      71      71  -1,297       1%
# 1      -1      -1    -222      -2      10      10     -79       4%
# 2     -17      -4  -6,861     -20     254     254  -2,470       1%
# 3       0      -1    -253       0      -3      -3     -93       2%
# 4     -38      -9  -4,607     -45     586     586  -1,633       3%
#
#   Env_intensity
# 0       -0.0289
# 1       -0.0168
# 2       -0.0153
# 3       -0.0146
# 4       -0.0070
#
# [5 rows x 35 columns]

# %% [markdown]
# Now, the dataset looks way better and we can continue our analysis by using this cleaned dataset. We will proceed to export the dataframe to the dataset folder from where we are going to access it in future notebooks.
#
# We are also going to add new columns to this dataset.
#
# ## Creating the Industry Average Year column

# %%
industry_avg = df.groupby('Industry(Exiobase)')[['Env_intensity']].mean().reset_index()
df['industry_avg'] = df['Env_intensity'].groupby(df['Industry(Exiobase)']).transform('mean')

# %%
def create_ind_year(df):
    if(df['Env_intensity'] > df['industry_avg_year']):
        return 1
    elif (df['Env_intensity'] == df['industry_avg_year']):
        return 0
    elif (df['Env_intensity'] < df['industry_avg_year']):
        return -1

df['industry_avg_year'] = df.groupby(['Industry(Exiobase)','Year']).transform('mean')[['Env_intensity']]

df['Industry_indicator_year'] = df.apply(create_ind_year, axis = 1)
df.head()
# Out:
#            ISIN  Year         CompanyName         Country  \
# 0  GB00BMX64W89  2019            Saga plc  United Kingdom
# 1  MYL1818OO003  2019  BURSA MALAYSIA BHD        Malaysia
# 2  GB0031638363  2019  INTERTEK GROUP PLC  United Kingdom
# 3  ZAE000079711  2019         JSE LIMITED    South Africa
# 4  FR0006174348  2019   BUREAU VERITAS SA          France
#
#                                   Industry(Exiobase)  \
# 0  Activities auxiliary to financial intermediati...
# 1  Activities auxiliary to financial intermediati...
# 2  Activities auxiliary to financial intermediati...
# 3  Activities auxiliary to financial intermediati...
# 4  Activities auxiliary to financial intermediati...
#
#   EnvironmentalIntensity(Sales) EnvironmentalIntensity(OpInc)  \
# 0                        -2.89%                       -13.03%
# 1                        -1.68%                        -3.47%
# 2                        -1.53%                        -9.49%
# 3                        -1.46%                           NaN
# 4                        -0.70%                        -5.10%
#
#   TotalEnvironmentalCost WorkingCapacity FishProductionCapacity  ... SDG14.3  \
# 0            -31,842,309     -31,150,754                 -7,184  ...  -3,585
# 1             -1,968,379      -1,924,910                   -451  ...    -222
# 2            -60,599,272     -59,281,663                -13,774  ...  -6,861
# 3             -2,290,124      -2,239,814                   -510  ...    -253
# 4            -39,978,650     -39,107,612                 -9,330  ...  -4,607
#
#   SDG14.c SDG15.1 SDG15.2 SDG15.5 %Imputed Env_intensity industry_avg  \
# 0      -6      71      71  -1,297       1%       -0.0289    -0.004417
# 1      -2      10      10     -79       4%       -0.0168    -0.004417
# 2     -20     254     254  -2,470       1%       -0.0153    -0.004417
# 3       0      -3      -3     -93       2%       -0.0146    -0.004417
# 4     -45     586     586  -1,633       3%       -0.0070    -0.004417
#
#   industry_avg_year Industry_indicator_year
# 0          0.002943                      -1
# 1          0.002943                      -1
# 2          0.002943                      -1
# 3          0.002943                      -1
# 4          0.002943                      -1
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Creating Environmental growth
#
# Environmental Intensity Growth : ((Environmental Intensity in Current Year / Environmental Intensity Last Year) - 1) * 100

# %%
df = df.sort_values(by=['CompanyName','Year'], ascending = True)
df['Environmental_Growth'] = df.groupby(['CompanyName'])['Env_intensity'].apply(lambda x: x.pct_change()).to_numpy() * 100
df.head()
# Out:
#                ISIN  Year       CompanyName         Country  \
# 6369   DE0005545503  2016  1&1 DRILLISCH AG         Germany
# 13777  GB00B1YW4409  2010      3I GROUP PLC  United Kingdom
# 12690  GB00B1YW4409  2011      3I GROUP PLC  United Kingdom
# 11504  GB00B1YW4409  2012      3I GROUP PLC  United Kingdom
# 13501  US88579Y1010  2010        3M COMPANY   United States
#
#                                       Industry(Exiobase)  \
# 6369                   Post and telecommunications (64)
# 13777   Financial intermediation, except insurance an...
# 12690   Financial intermediation, except insurance an...
# 11504   Financial intermediation, except insurance an...
# 13501   Activities of membership organisation n.e.c. ...
#
#       EnvironmentalIntensity(Sales) EnvironmentalIntensity(OpInc)  \
# 6369                         -0.07%                        -0.82%
# 13777                        -0.12%                        -0.11%
# 12690                        -0.16%                        -0.16%
# 11504                        -0.15%                           NaN
# 13501                        -7.90%                       -35.45%
#
#       TotalEnvironmentalCost WorkingCapacity FishProductionCapacity  ...  \
# 6369                -539,318        -525,027                   -169  ...
# 13777             -1,055,812      -1,032,103                   -277  ...
# 12690               -961,875        -940,402                   -246  ...
# 11504               -722,999        -706,893                   -183  ...
# 13501         -2,105,919,763  -1,924,672,080               -439,506  ...
#
#       SDG14.c SDG15.1 SDG15.2  SDG15.5 %Imputed Env_intensity industry_avg  \
# 6369       -6      67      67      -22      23%       -0.0007    -0.018382
# 13777      -4      51      51      -43      10%       -0.0012    -0.020072
# 12690      -3      38      38      -39       9%       -0.0016    -0.020072
# 11504      -2      27      27      -30       8%       -0.0015    -0.020072
# 13501    -423   3,772   3,772  -79,722       1%       -0.0790    -0.117561
#
#       industry_avg_year Industry_indicator_year Environmental_Growth
# 6369          -0.011640                       1                  NaN
# 13777         -0.006402                       1                  NaN
# 12690         -0.009838                       1            33.333333
# 11504         -0.024437                       1            -6.250000
# 13501         -0.084583                       1                  NaN
#
# [5 rows x 39 columns]

# %%
df.to_csv('/Users/maralinetorres/Documents/GitHub/Predicting-Environmental-and-Social-Actions/Datasets/Environmental_impact_cleaned.csv', index=False)
